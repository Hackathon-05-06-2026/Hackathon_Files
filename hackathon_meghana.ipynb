# %% [markdown]
# <a href="https://colab.research.google.com/github/Hackathon-05-06-2026/Hackathon_Files/blob/main/hackathon_meghana.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import files
import io
